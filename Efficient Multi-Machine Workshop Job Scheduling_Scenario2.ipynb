# %% [markdown]
# ## FOR 50 JOBS

# %% [markdown]
# ### IP ALGORITHM

# %%
import random

def generateData(machines=4, jobs=50, seed=7677):
    PROC = [ [ 0 for m in range(machines) ] for j in range(jobs) ]
    random.seed(seed)
    for j in range(jobs):
        for m in range(machines):
            PROC[j][m] = random.randint(1,9)
    return PROC

# %%
import pulp

def IP(PROC):

    steps = [ len(job) for job in PROC ]
    assert(min(steps)==max(steps))
    N_MACHINES = len(PROC[0])
    N_JOBS = len(PROC)


    def val(x):
        return int(pulp.value(x))

    def proc(job, machine):
        return pulp.lpSum( [ PROC[j][machine] * JJ[job][j] for j in range(N_JOBS) ] ) 

    JJ = pulp.LpVariable.dicts("J", (range(N_JOBS), range(N_JOBS)), lowBound=0, upBound=1, cat='Integer')
    Wait = pulp.LpVariable.dicts("WAIT", (range(N_JOBS), range(N_MACHINES)), lowBound=0, cat='Integer')
    Idle = pulp.LpVariable.dicts("IDLE", (range(N_JOBS), range(N_MACHINES)), lowBound=0, cat='Integer')
    Start = pulp.LpVariable.dicts("START", (range(N_JOBS), range(N_MACHINES)), lowBound=0, cat='Integer')
    Stop = pulp.LpVariable.dicts("STOP", (range(N_JOBS), range(N_MACHINES)), lowBound=0, cat='Integer')

    prob = pulp.LpProblem("JobScheduling",pulp.LpMinimize)
    prob += Stop[N_JOBS-1][N_MACHINES-1]

    # JJ is a permutation of the jobs
    for j in range(N_JOBS):
        prob += pulp.lpSum( [ JJ[j][jj] for jj in range(N_JOBS) ] ) == 1
        prob += pulp.lpSum( [ JJ[jj][j] for jj in range(N_JOBS) ] ) == 1

    for m in range(N_MACHINES):
        for j in range(N_JOBS):
            prob += pulp.lpSum( [ Idle[ji][m] + proc(ji, m) for ji in range(j) ] ) + Idle[j][m] == Start[j][m]

    for m in range(N_MACHINES):
        for j in range(N_JOBS):
            prob += pulp.lpSum( [ Wait[j][mi] + proc(j, mi) for mi in range(m) ] ) + Wait[j][m] == Start[j][m]

    for j in range(N_JOBS):
        for m in range(N_MACHINES):
            prob += Start[j][m] + proc(j,m) == Stop[j][m]

    solvers = pulp.listSolvers(onlyAvailable=True) 
    solver = pulp.getSolver(solvers[0], msg=0)
    prob.solve(solver)

    acc = []
    for j in range(N_JOBS):
        for jj in range(N_JOBS):
            if pulp.value(JJ[j][jj])==1:
                acc.append(jj)
                
    return acc, int(pulp.value(prob.objective))

# %%
import numpy as np

def totalTime(PROC, seq, log=False):
    
    def isPermutation(seq):
        for i in range(len(seq)):
            if i not in seq:
                return False
        return True
    
    steps = [ len(job) for job in PROC ]
    assert(len(PROC) == len(seq))
    assert(isPermutation(seq))
    assert(min(steps)==max(steps))
    n_machines = len(PROC[0])
    n_jobs = len(PROC)
    wait = np.zeros([n_jobs, n_machines], dtype=int)
    idle = np.zeros([n_jobs, n_machines], dtype=int)
    start = np.zeros([n_jobs, n_machines], dtype=int)
    stop  = np.zeros([n_jobs, n_machines], dtype=int)
    proc = np.zeros([n_jobs, n_machines], dtype=int)
    for job in range(n_jobs):
        proc[job] = PROC[seq[job]]
    for job in range(n_jobs):
        for machine in range(n_machines):
            start[job, machine] = max(stop[job-1, machine] if job>0 else 0, stop[job, machine-1] if machine>0 else 0)
            wait[job, machine] = start[job, machine] - (stop[job, machine-1] if machine>0 else 0)
            idle[job, machine] = start[job, machine] - (stop[job-1, machine] if job>0 else 0)
            stop[job, machine] = start[job, machine] + proc[job, machine]

    if log:

        row = '|---------|'
        for m in range(n_machines):
            row += f"------------|" \
                    f"------------|"
        print(row)
        
        row = '|         |'
        for m in range(n_machines):
            row += f"            |" \
                    f" Machine: {m:1d} |"
        print(row)
        
        for j in range(n_jobs):
            
            row = '|---------|'
            for m in range(n_machines):
                row += f"------------|" \
                       f"------------|"
            print(row)
            
            row = '|         |'
            for m in range(n_machines):
                row += f"       {' ':4s} | " \
                       f"Idle: {idle[j,m]:4d} |"
            print(row)
            
            row = '|---------|'
            for m in range(n_machines):
                row += f"------------|" \
                       f"------------|"
            print(row)
            
            row = '|         |'
            for m in range(n_machines):
                row += f"       {' ':4s} | " \
                       f"Start:{start[j,m]:4d} |"  
            print(row)
            
            row = f'| Job: {seq[j]:2d} |'
            for m in range(n_machines):
                row += f" Wait: {wait[j,m]:4d} | " \
                       f"Proc: {proc[j,m]:4d} |"
            print(row)
            
            row = '|         |'
            for m in range(n_machines):
                row += f"       {' ':4s} | " \
                       f"Stop: {stop[j,m]:4d} |"  
            print(row)
            
        row = '|---------|'
        for m in range(n_machines):
            row += f"------------|" \
                    f"------------|"
        print(row)

    
    return stop[n_jobs-1, n_machines-1]

# %%
PROC = generateData(machines=4, jobs=50, seed=7677)

# %% [markdown]
# Compute the optimal job schedule:

# %%
seq, proctime = IP(PROC)
print(seq)
print(proctime)
# Out:
# [17, 1, 39, 4, 33, 21, 20, 48, 18, 27, 49, 31, 14, 15, 38, 41, 46, 23, 42, 37, 47, 16, 13, 0, 45, 9, 25, 35, 29, 5, 6, 8, 26, 2, 24, 44, 11, 10, 36, 22, 12, 7, 43, 28, 30, 34, 3, 19, 40, 32]
# 262

# %% [markdown]
# Check the processing time and print the schedule

# %%
totalTime(PROC, seq)
# Out:
# 262

# %%
totalTime(PROC, seq, log=True)
# Out:
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    5 |            | Idle:    6 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   5 |            | Start:   6 |
# | Job: 17 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    8 |
# |         |            | Stop:    1 |            | Stop:    5 |            | Stop:    6 |            | Stop:   14 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   5 |            | Start:   6 |            | Start:  14 |
# | Job:  1 | Wait:    1 | Proc:    2 | Wait:    2 | Proc:    1 | Wait:    0 | Proc:    3 | Wait:    5 | Proc:    2 |
# |         |            | Stop:    3 |            | Stop:    6 |            | Stop:    9 |            | Stop:   16 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   3 |            | Start:   6 |            | Start:   9 |            | Start:  16 |
# | Job: 39 | Wait:    3 | Proc:    1 | Wait:    2 | Proc:    2 | Wait:    1 | Proc:    5 | Wait:    2 | Proc:    3 |
# |         |            | Stop:    4 |            | Stop:    8 |            | Stop:   14 |            | Stop:   19 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   4 |            | Start:   8 |            | Start:  14 |            | Start:  19 |
# | Job:  4 | Wait:    4 | Proc:    2 | Wait:    2 | Proc:    3 | Wait:    3 | Proc:    2 | Wait:    3 | Proc:    8 |
# |         |            | Stop:    6 |            | Stop:   11 |            | Stop:   16 |            | Stop:   27 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   6 |            | Start:  11 |            | Start:  16 |            | Start:  27 |
# | Job: 33 | Wait:    6 | Proc:    3 | Wait:    2 | Proc:    1 | Wait:    4 | Proc:    4 | Wait:    7 | Proc:    8 |
# |         |            | Stop:    9 |            | Stop:   12 |            | Stop:   20 |            | Stop:   35 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   9 |            | Start:  12 |            | Start:  20 |            | Start:  35 |
# | Job: 21 | Wait:    9 | Proc:    3 | Wait:    0 | Proc:    1 | Wait:    7 | Proc:    5 | Wait:   10 | Proc:    2 |
# |         |            | Stop:   12 |            | Stop:   13 |            | Stop:   25 |            | Stop:   37 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  12 |            | Start:  13 |            | Start:  25 |            | Start:  37 |
# | Job: 20 | Wait:   12 | Proc:    1 | Wait:    0 | Proc:    2 | Wait:   10 | Proc:    9 | Wait:    3 | Proc:    9 |
# |         |            | Stop:   13 |            | Stop:   15 |            | Stop:   34 |            | Stop:   46 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  15 |            | Start:  34 |            | Start:  46 |
# | Job: 48 | Wait:   13 | Proc:    2 | Wait:    0 | Proc:    1 | Wait:   18 | Proc:    7 | Wait:    5 | Proc:    7 |
# |         |            | Stop:   15 |            | Stop:   16 |            | Stop:   41 |            | Stop:   53 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  15 |            | Start:  16 |            | Start:  41 |            | Start:  53 |
# | Job: 18 | Wait:   15 | Proc:    1 | Wait:    0 | Proc:    5 | Wait:   20 | Proc:    4 | Wait:    8 | Proc:    8 |
# |         |            | Stop:   16 |            | Stop:   21 |            | Stop:   45 |            | Stop:   61 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  16 |            | Start:  21 |            | Start:  45 |            | Start:  61 |
# | Job: 27 | Wait:   16 | Proc:    3 | Wait:    2 | Proc:    4 | Wait:   20 | Proc:    1 | Wait:   15 | Proc:    9 |
# |         |            | Stop:   19 |            | Stop:   25 |            | Stop:   46 |            | Stop:   70 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  19 |            | Start:  25 |            | Start:  46 |            | Start:  70 |
# | Job: 49 | Wait:   19 | Proc:    2 | Wait:    4 | Proc:    6 | Wait:   15 | Proc:    4 | Wait:   20 | Proc:    2 |
# |         |            | Stop:   21 |            | Stop:   31 |            | Stop:   50 |            | Stop:   72 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  21 |            | Start:  31 |            | Start:  50 |            | Start:  72 |
# | Job: 31 | Wait:   21 | Proc:    4 | Wait:    6 | Proc:    4 | Wait:   15 | Proc:    1 | Wait:   21 | Proc:    3 |
# |         |            | Stop:   25 |            | Stop:   35 |            | Stop:   51 |            | Stop:   75 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  25 |            | Start:  35 |            | Start:  51 |            | Start:  75 |
# | Job: 14 | Wait:   25 | Proc:    5 | Wait:    5 | Proc:    1 | Wait:   15 | Proc:    7 | Wait:   17 | Proc:    3 |
# |         |            | Stop:   30 |            | Stop:   36 |            | Stop:   58 |            | Stop:   78 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  30 |            | Start:  36 |            | Start:  58 |            | Start:  78 |
# | Job: 15 | Wait:   30 | Proc:    4 | Wait:    2 | Proc:    3 | Wait:   19 | Proc:    3 | Wait:   17 | Proc:    6 |
# |         |            | Stop:   34 |            | Stop:   39 |            | Stop:   61 |            | Stop:   84 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  34 |            | Start:  39 |            | Start:  61 |            | Start:  84 |
# | Job: 38 | Wait:   34 | Proc:    4 | Wait:    1 | Proc:    3 | Wait:   19 | Proc:    6 | Wait:   17 | Proc:    4 |
# |         |            | Stop:   38 |            | Stop:   42 |            | Stop:   67 |            | Stop:   88 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  38 |            | Start:  42 |            | Start:  67 |            | Start:  88 |
# | Job: 41 | Wait:   38 | Proc:    1 | Wait:    3 | Proc:    7 | Wait:   18 | Proc:    4 | Wait:   17 | Proc:    9 |
# |         |            | Stop:   39 |            | Stop:   49 |            | Stop:   71 |            | Stop:   97 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  39 |            | Start:  49 |            | Start:  71 |            | Start:  97 |
# | Job: 46 | Wait:   39 | Proc:    3 | Wait:    7 | Proc:    4 | Wait:   18 | Proc:    6 | Wait:   20 | Proc:    4 |
# |         |            | Stop:   42 |            | Stop:   53 |            | Stop:   77 |            | Stop:  101 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  42 |            | Start:  53 |            | Start:  77 |            | Start: 101 |
# | Job: 23 | Wait:   42 | Proc:    4 | Wait:    7 | Proc:    3 | Wait:   21 | Proc:    4 | Wait:   20 | Proc:    8 |
# |         |            | Stop:   46 |            | Stop:   56 |            | Stop:   81 |            | Stop:  109 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  46 |            | Start:  56 |            | Start:  81 |            | Start: 109 |
# | Job: 42 | Wait:   46 | Proc:    4 | Wait:    6 | Proc:    5 | Wait:   20 | Proc:    1 | Wait:   27 | Proc:    8 |
# |         |            | Stop:   50 |            | Stop:   61 |            | Stop:   82 |            | Stop:  117 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  50 |            | Start:  61 |            | Start:  82 |            | Start: 117 |
# | Job: 37 | Wait:   50 | Proc:    4 | Wait:    7 | Proc:    3 | Wait:   18 | Proc:    7 | Wait:   28 | Proc:    5 |
# |         |            | Stop:   54 |            | Stop:   64 |            | Stop:   89 |            | Stop:  122 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  54 |            | Start:  64 |            | Start:  89 |            | Start: 122 |
# | Job: 47 | Wait:   54 | Proc:    1 | Wait:    9 | Proc:    9 | Wait:   16 | Proc:    5 | Wait:   28 | Proc:    4 |
# |         |            | Stop:   55 |            | Stop:   73 |            | Stop:   94 |            | Stop:  126 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  55 |            | Start:  73 |            | Start:  94 |            | Start: 126 |
# | Job: 16 | Wait:   55 | Proc:    2 | Wait:   16 | Proc:    9 | Wait:   12 | Proc:    5 | Wait:   27 | Proc:    2 |
# |         |            | Stop:   57 |            | Stop:   82 |            | Stop:   99 |            | Stop:  128 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  57 |            | Start:  82 |            | Start:  99 |            | Start: 128 |
# | Job: 13 | Wait:   57 | Proc:    3 | Wait:   22 | Proc:    5 | Wait:   12 | Proc:    6 | Wait:   23 | Proc:    1 |
# |         |            | Stop:   60 |            | Stop:   87 |            | Stop:  105 |            | Stop:  129 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  60 |            | Start:  87 |            | Start: 105 |            | Start: 129 |
# | Job:  0 | Wait:   60 | Proc:    5 | Wait:   22 | Proc:    1 | Wait:   17 | Proc:    9 | Wait:   15 | Proc:    7 |
# |         |            | Stop:   65 |            | Stop:   88 |            | Stop:  114 |            | Stop:  136 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  65 |            | Start:  88 |            | Start: 114 |            | Start: 136 |
# | Job: 45 | Wait:   65 | Proc:    5 | Wait:   18 | Proc:    3 | Wait:   23 | Proc:    8 | Wait:   14 | Proc:    4 |
# |         |            | Stop:   70 |            | Stop:   91 |            | Stop:  122 |            | Stop:  140 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  70 |            | Start:  91 |            | Start: 122 |            | Start: 140 |
# | Job:  9 | Wait:   70 | Proc:    3 | Wait:   18 | Proc:    8 | Wait:   23 | Proc:    2 | Wait:   16 | Proc:    5 |
# |         |            | Stop:   73 |            | Stop:   99 |            | Stop:  124 |            | Stop:  145 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  73 |            | Start:  99 |            | Start: 124 |            | Start: 145 |
# | Job: 25 | Wait:   73 | Proc:    6 | Wait:   20 | Proc:    3 | Wait:   22 | Proc:    6 | Wait:   15 | Proc:    2 |
# |         |            | Stop:   79 |            | Stop:  102 |            | Stop:  130 |            | Stop:  147 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  79 |            | Start: 102 |            | Start: 130 |            | Start: 147 |
# | Job: 35 | Wait:   79 | Proc:    5 | Wait:   18 | Proc:    7 | Wait:   21 | Proc:    3 | Wait:   14 | Proc:    1 |
# |         |            | Stop:   84 |            | Stop:  109 |            | Stop:  133 |            | Stop:  148 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  84 |            | Start: 109 |            | Start: 133 |            | Start: 148 |
# | Job: 29 | Wait:   84 | Proc:    6 | Wait:   19 | Proc:    2 | Wait:   22 | Proc:    5 | Wait:   10 | Proc:    6 |
# |         |            | Stop:   90 |            | Stop:  111 |            | Stop:  138 |            | Stop:  154 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  90 |            | Start: 111 |            | Start: 138 |            | Start: 154 |
# | Job:  5 | Wait:   90 | Proc:    3 | Wait:   18 | Proc:    7 | Wait:   20 | Proc:    5 | Wait:   11 | Proc:    6 |
# |         |            | Stop:   93 |            | Stop:  118 |            | Stop:  143 |            | Stop:  160 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  93 |            | Start: 118 |            | Start: 143 |            | Start: 160 |
# | Job:  6 | Wait:   93 | Proc:    8 | Wait:   17 | Proc:    3 | Wait:   22 | Proc:    2 | Wait:   15 | Proc:    1 |
# |         |            | Stop:  101 |            | Stop:  121 |            | Stop:  145 |            | Stop:  161 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 101 |            | Start: 121 |            | Start: 145 |            | Start: 161 |
# | Job:  8 | Wait:  101 | Proc:    3 | Wait:   17 | Proc:    7 | Wait:   17 | Proc:    4 | Wait:   12 | Proc:    7 |
# |         |            | Stop:  104 |            | Stop:  128 |            | Stop:  149 |            | Stop:  168 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 104 |            | Start: 128 |            | Start: 149 |            | Start: 168 |
# | Job: 26 | Wait:  104 | Proc:    9 | Wait:   15 | Proc:    1 | Wait:   20 | Proc:    3 | Wait:   16 | Proc:    2 |
# |         |            | Stop:  113 |            | Stop:  129 |            | Stop:  152 |            | Stop:  170 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 113 |            | Start: 129 |            | Start: 152 |            | Start: 170 |
# | Job:  2 | Wait:  113 | Proc:    9 | Wait:    7 | Proc:    2 | Wait:   21 | Proc:    5 | Wait:   13 | Proc:    1 |
# |         |            | Stop:  122 |            | Stop:  131 |            | Stop:  157 |            | Stop:  171 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 122 |            | Start: 131 |            | Start: 157 |            | Start: 171 |
# | Job: 24 | Wait:  122 | Proc:    6 | Wait:    3 | Proc:    8 | Wait:   18 | Proc:    2 | Wait:   12 | Proc:    2 |
# |         |            | Stop:  128 |            | Stop:  139 |            | Stop:  159 |            | Stop:  173 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 128 |            | Start: 139 |            | Start: 159 |            | Start: 173 |
# | Job: 44 | Wait:  128 | Proc:    7 | Wait:    4 | Proc:    2 | Wait:   18 | Proc:    2 | Wait:   12 | Proc:    8 |
# |         |            | Stop:  135 |            | Stop:  141 |            | Stop:  161 |            | Stop:  181 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 135 |            | Start: 141 |            | Start: 161 |            | Start: 181 |
# | Job: 11 | Wait:  135 | Proc:    5 | Wait:    1 | Proc:    4 | Wait:   16 | Proc:    5 | Wait:   15 | Proc:    7 |
# |         |            | Stop:  140 |            | Stop:  145 |            | Stop:  166 |            | Stop:  188 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 140 |            | Start: 145 |            | Start: 166 |            | Start: 188 |
# | Job: 10 | Wait:  140 | Proc:    5 | Wait:    0 | Proc:    9 | Wait:   12 | Proc:    8 | Wait:   14 | Proc:    1 |
# |         |            | Stop:  145 |            | Stop:  154 |            | Stop:  174 |            | Stop:  189 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 145 |            | Start: 154 |            | Start: 174 |            | Start: 189 |
# | Job: 36 | Wait:  145 | Proc:    8 | Wait:    1 | Proc:    6 | Wait:   14 | Proc:    6 | Wait:    9 | Proc:    2 |
# |         |            | Stop:  153 |            | Stop:  160 |            | Stop:  180 |            | Stop:  191 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 153 |            | Start: 160 |            | Start: 180 |            | Start: 191 |
# | Job: 22 | Wait:  153 | Proc:    6 | Wait:    1 | Proc:    2 | Wait:   18 | Proc:    9 | Wait:    2 | Proc:    6 |
# |         |            | Stop:  159 |            | Stop:  162 |            | Stop:  189 |            | Stop:  197 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    5 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 159 |            | Start: 167 |            | Start: 189 |            | Start: 197 |
# | Job: 12 | Wait:  159 | Proc:    8 | Wait:    0 | Proc:    7 | Wait:   15 | Proc:    2 | Wait:    6 | Proc:    5 |
# |         |            | Stop:  167 |            | Stop:  174 |            | Stop:  191 |            | Stop:  202 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 167 |            | Start: 174 |            | Start: 191 |            | Start: 202 |
# | Job:  7 | Wait:  167 | Proc:    5 | Wait:    2 | Proc:    7 | Wait:   10 | Proc:    2 | Wait:    9 | Proc:    8 |
# |         |            | Stop:  172 |            | Stop:  181 |            | Stop:  193 |            | Stop:  210 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 172 |            | Start: 181 |            | Start: 193 |            | Start: 210 |
# | Job: 43 | Wait:  172 | Proc:    8 | Wait:    1 | Proc:    8 | Wait:    4 | Proc:    3 | Wait:   14 | Proc:    1 |
# |         |            | Stop:  180 |            | Stop:  189 |            | Stop:  196 |            | Stop:  211 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 180 |            | Start: 189 |            | Start: 196 |            | Start: 211 |
# | Job: 28 | Wait:  180 | Proc:    6 | Wait:    3 | Proc:    5 | Wait:    2 | Proc:    8 | Wait:    7 | Proc:    9 |
# |         |            | Stop:  186 |            | Stop:  194 |            | Stop:  204 |            | Stop:  220 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 186 |            | Start: 195 |            | Start: 204 |            | Start: 220 |
# | Job: 30 | Wait:  186 | Proc:    9 | Wait:    0 | Proc:    8 | Wait:    1 | Proc:    3 | Wait:   13 | Proc:    6 |
# |         |            | Stop:  195 |            | Stop:  203 |            | Stop:  207 |            | Stop:  226 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    4 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 195 |            | Start: 204 |            | Start: 211 |            | Start: 226 |
# | Job: 34 | Wait:  195 | Proc:    9 | Wait:    0 | Proc:    7 | Wait:    0 | Proc:    7 | Wait:    8 | Proc:    3 |
# |         |            | Stop:  204 |            | Stop:  211 |            | Stop:  218 |            | Stop:  229 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    2 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 204 |            | Start: 213 |            | Start: 220 |            | Start: 229 |
# | Job:  3 | Wait:  204 | Proc:    9 | Wait:    0 | Proc:    7 | Wait:    0 | Proc:    6 | Wait:    3 | Proc:    9 |
# |         |            | Stop:  213 |            | Stop:  220 |            | Stop:  226 |            | Stop:  238 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    2 |            | Idle:    4 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 213 |            | Start: 222 |            | Start: 230 |            | Start: 238 |
# | Job: 19 | Wait:  213 | Proc:    9 | Wait:    0 | Proc:    8 | Wait:    0 | Proc:    1 | Wait:    7 | Proc:    8 |
# |         |            | Stop:  222 |            | Stop:  230 |            | Stop:  231 |            | Stop:  246 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 222 |            | Start: 231 |            | Start: 232 |            | Start: 246 |
# | Job: 40 | Wait:  222 | Proc:    9 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:   10 | Proc:    9 |
# |         |            | Stop:  231 |            | Stop:  232 |            | Stop:  236 |            | Stop:  255 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    7 |            | Idle:    4 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 231 |            | Start: 239 |            | Start: 240 |            | Start: 255 |
# | Job: 32 | Wait:  231 | Proc:    8 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    2 | Wait:   13 | Proc:    7 |
# |         |            | Stop:  239 |            | Stop:  240 |            | Stop:  242 |            | Stop:  262 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# 262

# %% [markdown]
# ## Genetic Algorithm

# %%
import numpy as np
import random

def genetic_algorithm(PROC, population_size=100, generations=100, crossover_rate=0.8, mutation_rate=0.1):
    def create_individual():
        return random.sample(range(len(PROC)), len(PROC))

    def crossover(parent1, parent2):
        size = len(parent1)
        child = [-1] * size
        start, end = sorted(random.sample(range(size), 2))
        child[start:end+1] = parent1[start:end+1]
        pointer = 0
        for i in range(size):
            if child[i] == -1:
                while parent2[pointer] in child:
                    pointer += 1
                child[i] = parent2[pointer]
        return child

    def mutate(individual):
        i, j = random.sample(range(len(individual)), 2)
        individual[i], individual[j] = individual[j], individual[i]

    def selection(population):
        return random.choices(population, weights=[1/fitness(ind) for ind in population], k=2)

    def fitness(individual):
        return totalTime(PROC, individual)

    # Initial population
    population = [create_individual() for _ in range(population_size)]
    best_individual = min(population, key=fitness)
    best_fitness = fitness(best_individual)

    for generation in range(generations):
        new_population = []
        for _ in range(population_size // 2):
            parent1, parent2 = selection(population)
            if random.random() < crossover_rate:
                child1 = crossover(parent1, parent2)
                child2 = crossover(parent2, parent1)
            else:
                child1, child2 = parent1[:], parent2[:]
            if random.random() < mutation_rate:
                mutate(child1)
            if random.random() < mutation_rate:
                mutate(child2)
            new_population.extend([child1, child2])

        population = new_population
        current_best = min(population, key=fitness)
        current_best_fitness = fitness(current_best)

        if current_best_fitness < best_fitness:
            best_individual = current_best
            best_fitness = current_best_fitness

        print(f"Generation {generation+1}/{generations}: Best Time = {best_fitness}")

    return best_individual, best_fitness

# %%
# The genetic algorithm usage
best_seq, best_time = genetic_algorithm(PROC)

# Printing the best sequence and time found by the genetic algorithm
print(f"Best sequence: {best_seq}")
print(f"Best total time: {best_time}")

# detailed log of processing for the best sequence
totalTime(PROC, best_seq, log=True)
# Out:
# Generation 1/100: Best Time = 269
# Generation 2/100: Best Time = 268
# Generation 3/100: Best Time = 268
# Generation 4/100: Best Time = 268
# Generation 5/100: Best Time = 268
# Generation 6/100: Best Time = 268
# Generation 7/100: Best Time = 268
# Generation 8/100: Best Time = 268
# Generation 9/100: Best Time = 268
# Generation 10/100: Best Time = 268
# Generation 11/100: Best Time = 268
# Generation 12/100: Best Time = 268
# Generation 13/100: Best Time = 268
# Generation 14/100: Best Time = 268
# Generation 15/100: Best Time = 267
# Generation 16/100: Best Time = 267
# Generation 17/100: Best Time = 267
# Generation 18/100: Best Time = 267
# Generation 19/100: Best Time = 267
# Generation 20/100: Best Time = 267
# Generation 21/100: Best Time = 267
# Generation 22/100: Best Time = 267
# Generation 23/100: Best Time = 267
# Generation 24/100: Best Time = 265
# Generation 25/100: Best Time = 265
# Generation 26/100: Best Time = 265
# Generation 27/100: Best Time = 265
# Generation 28/100: Best Time = 265
# Generation 29/100: Best Time = 265
# Generation 30/100: Best Time = 265
# Generation 31/100: Best Time = 265
# Generation 32/100: Best Time = 265
# Generation 33/100: Best Time = 265
# Generation 34/100: Best Time = 265
# Generation 35/100: Best Time = 265
# Generation 36/100: Best Time = 265
# Generation 37/100: Best Time = 265
# Generation 38/100: Best Time = 265
# Generation 39/100: Best Time = 265
# Generation 40/100: Best Time = 265
# Generation 41/100: Best Time = 265
# Generation 42/100: Best Time = 265
# Generation 43/100: Best Time = 265
# Generation 44/100: Best Time = 265
# Generation 45/100: Best Time = 265
# Generation 46/100: Best Time = 265
# Generation 47/100: Best Time = 265
# Generation 48/100: Best Time = 265
# Generation 49/100: Best Time = 265
# Generation 50/100: Best Time = 265
# Generation 51/100: Best Time = 265
# Generation 52/100: Best Time = 265
# Generation 53/100: Best Time = 265
# Generation 54/100: Best Time = 265
# Generation 55/100: Best Time = 265
# Generation 56/100: Best Time = 265
# Generation 57/100: Best Time = 265
# Generation 58/100: Best Time = 265
# Generation 59/100: Best Time = 265
# Generation 60/100: Best Time = 265
# Generation 61/100: Best Time = 265
# Generation 62/100: Best Time = 265
# Generation 63/100: Best Time = 265
# Generation 64/100: Best Time = 265
# Generation 65/100: Best Time = 265
# Generation 66/100: Best Time = 265
# Generation 67/100: Best Time = 265
# Generation 68/100: Best Time = 265
# Generation 69/100: Best Time = 265
# Generation 70/100: Best Time = 265
# Generation 71/100: Best Time = 265
# Generation 72/100: Best Time = 265
# Generation 73/100: Best Time = 265
# Generation 74/100: Best Time = 265
# Generation 75/100: Best Time = 265
# Generation 76/100: Best Time = 265
# Generation 77/100: Best Time = 265
# Generation 78/100: Best Time = 265
# Generation 79/100: Best Time = 265
# Generation 80/100: Best Time = 265
# Generation 81/100: Best Time = 265
# Generation 82/100: Best Time = 265
# Generation 83/100: Best Time = 265
# Generation 84/100: Best Time = 265
# Generation 85/100: Best Time = 265
# Generation 86/100: Best Time = 265
# Generation 87/100: Best Time = 265
# Generation 88/100: Best Time = 265
# Generation 89/100: Best Time = 265
# Generation 90/100: Best Time = 265
# Generation 91/100: Best Time = 265
# Generation 92/100: Best Time = 265
# Generation 93/100: Best Time = 265
# Generation 94/100: Best Time = 265
# Generation 95/100: Best Time = 265
# Generation 96/100: Best Time = 265
# Generation 97/100: Best Time = 265
# Generation 98/100: Best Time = 265
# Generation 99/100: Best Time = 265
# Generation 100/100: Best Time = 265
# Best sequence: [39, 23, 48, 31, 17, 3, 11, 10, 42, 49, 4, 20, 16, 5, 43, 38, 27, 6, 29, 30, 18, 26, 21, 9, 15, 1, 14, 45, 32, 47, 44, 22, 46, 12, 41, 33, 19, 34, 0, 28, 37, 40, 36, 7, 25, 35, 13, 24, 8, 2]
# Best total time: 265
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    3 |            | Idle:    8 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   3 |            | Start:   8 |
# | Job: 39 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    2 | Wait:    0 | Proc:    5 | Wait:    0 | Proc:    3 |
# |         |            | Stop:    1 |            | Stop:    3 |            | Stop:    8 |            | Stop:   11 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   5 |            | Start:   8 |            | Start:  12 |
# | Job: 23 | Wait:    1 | Proc:    4 | Wait:    0 | Proc:    3 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    8 |
# |         |            | Stop:    5 |            | Stop:    8 |            | Stop:   12 |            | Stop:   20 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   5 |            | Start:   8 |            | Start:  12 |            | Start:  20 |
# | Job: 48 | Wait:    5 | Proc:    2 | Wait:    1 | Proc:    1 | Wait:    3 | Proc:    7 | Wait:    1 | Proc:    7 |
# |         |            | Stop:    7 |            | Stop:    9 |            | Stop:   19 |            | Stop:   27 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   7 |            | Start:  11 |            | Start:  19 |            | Start:  27 |
# | Job: 31 | Wait:    7 | Proc:    4 | Wait:    0 | Proc:    4 | Wait:    4 | Proc:    1 | Wait:    7 | Proc:    3 |
# |         |            | Stop:   11 |            | Stop:   15 |            | Stop:   20 |            | Stop:   30 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  11 |            | Start:  15 |            | Start:  20 |            | Start:  30 |
# | Job: 17 | Wait:   11 | Proc:    1 | Wait:    3 | Proc:    4 | Wait:    1 | Proc:    1 | Wait:    9 | Proc:    8 |
# |         |            | Stop:   12 |            | Stop:   19 |            | Stop:   21 |            | Stop:   38 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    2 |            | Idle:    7 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  12 |            | Start:  21 |            | Start:  28 |            | Start:  38 |
# | Job:  3 | Wait:   12 | Proc:    9 | Wait:    0 | Proc:    7 | Wait:    0 | Proc:    6 | Wait:    4 | Proc:    9 |
# |         |            | Stop:   21 |            | Stop:   28 |            | Stop:   34 |            | Stop:   47 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  21 |            | Start:  28 |            | Start:  34 |            | Start:  47 |
# | Job: 11 | Wait:   21 | Proc:    5 | Wait:    2 | Proc:    4 | Wait:    2 | Proc:    5 | Wait:    8 | Proc:    7 |
# |         |            | Stop:   26 |            | Stop:   32 |            | Stop:   39 |            | Stop:   54 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  26 |            | Start:  32 |            | Start:  41 |            | Start:  54 |
# | Job: 10 | Wait:   26 | Proc:    5 | Wait:    1 | Proc:    9 | Wait:    0 | Proc:    8 | Wait:    5 | Proc:    1 |
# |         |            | Stop:   31 |            | Stop:   41 |            | Stop:   49 |            | Stop:   55 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  31 |            | Start:  41 |            | Start:  49 |            | Start:  55 |
# | Job: 42 | Wait:   31 | Proc:    4 | Wait:    6 | Proc:    5 | Wait:    3 | Proc:    1 | Wait:    5 | Proc:    8 |
# |         |            | Stop:   35 |            | Stop:   46 |            | Stop:   50 |            | Stop:   63 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  35 |            | Start:  46 |            | Start:  52 |            | Start:  63 |
# | Job: 49 | Wait:   35 | Proc:    2 | Wait:    9 | Proc:    6 | Wait:    0 | Proc:    4 | Wait:    7 | Proc:    2 |
# |         |            | Stop:   37 |            | Stop:   52 |            | Stop:   56 |            | Stop:   65 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  37 |            | Start:  52 |            | Start:  56 |            | Start:  65 |
# | Job:  4 | Wait:   37 | Proc:    2 | Wait:   13 | Proc:    3 | Wait:    1 | Proc:    2 | Wait:    7 | Proc:    8 |
# |         |            | Stop:   39 |            | Stop:   55 |            | Stop:   58 |            | Stop:   73 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  39 |            | Start:  55 |            | Start:  58 |            | Start:  73 |
# | Job: 20 | Wait:   39 | Proc:    1 | Wait:   15 | Proc:    2 | Wait:    1 | Proc:    9 | Wait:    6 | Proc:    9 |
# |         |            | Stop:   40 |            | Stop:   57 |            | Stop:   67 |            | Stop:   82 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  40 |            | Start:  57 |            | Start:  67 |            | Start:  82 |
# | Job: 16 | Wait:   40 | Proc:    2 | Wait:   15 | Proc:    9 | Wait:    1 | Proc:    5 | Wait:   10 | Proc:    2 |
# |         |            | Stop:   42 |            | Stop:   66 |            | Stop:   72 |            | Stop:   84 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  42 |            | Start:  66 |            | Start:  73 |            | Start:  84 |
# | Job:  5 | Wait:   42 | Proc:    3 | Wait:   21 | Proc:    7 | Wait:    0 | Proc:    5 | Wait:    6 | Proc:    6 |
# |         |            | Stop:   45 |            | Stop:   73 |            | Stop:   78 |            | Stop:   90 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    3 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  45 |            | Start:  73 |            | Start:  81 |            | Start:  90 |
# | Job: 43 | Wait:   45 | Proc:    8 | Wait:   20 | Proc:    8 | Wait:    0 | Proc:    3 | Wait:    6 | Proc:    1 |
# |         |            | Stop:   53 |            | Stop:   81 |            | Stop:   84 |            | Stop:   91 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  53 |            | Start:  81 |            | Start:  84 |            | Start:  91 |
# | Job: 38 | Wait:   53 | Proc:    4 | Wait:   24 | Proc:    3 | Wait:    0 | Proc:    6 | Wait:    1 | Proc:    4 |
# |         |            | Stop:   57 |            | Stop:   84 |            | Stop:   90 |            | Stop:   95 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  57 |            | Start:  84 |            | Start:  90 |            | Start:  95 |
# | Job: 27 | Wait:   57 | Proc:    3 | Wait:   24 | Proc:    4 | Wait:    2 | Proc:    1 | Wait:    4 | Proc:    9 |
# |         |            | Stop:   60 |            | Stop:   88 |            | Stop:   91 |            | Stop:  104 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  60 |            | Start:  88 |            | Start:  91 |            | Start: 104 |
# | Job:  6 | Wait:   60 | Proc:    8 | Wait:   20 | Proc:    3 | Wait:    0 | Proc:    2 | Wait:   11 | Proc:    1 |
# |         |            | Stop:   68 |            | Stop:   91 |            | Stop:   93 |            | Stop:  105 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  68 |            | Start:  91 |            | Start:  93 |            | Start: 105 |
# | Job: 29 | Wait:   68 | Proc:    6 | Wait:   17 | Proc:    2 | Wait:    0 | Proc:    5 | Wait:    7 | Proc:    6 |
# |         |            | Stop:   74 |            | Stop:   93 |            | Stop:   98 |            | Stop:  111 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    3 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  74 |            | Start:  93 |            | Start: 101 |            | Start: 111 |
# | Job: 30 | Wait:   74 | Proc:    9 | Wait:   10 | Proc:    8 | Wait:    0 | Proc:    3 | Wait:    7 | Proc:    6 |
# |         |            | Stop:   83 |            | Stop:  101 |            | Stop:  104 |            | Stop:  117 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  83 |            | Start: 101 |            | Start: 106 |            | Start: 117 |
# | Job: 18 | Wait:   83 | Proc:    1 | Wait:   17 | Proc:    5 | Wait:    0 | Proc:    4 | Wait:    7 | Proc:    8 |
# |         |            | Stop:   84 |            | Stop:  106 |            | Stop:  110 |            | Stop:  125 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  84 |            | Start: 106 |            | Start: 110 |            | Start: 125 |
# | Job: 26 | Wait:   84 | Proc:    9 | Wait:   13 | Proc:    1 | Wait:    3 | Proc:    3 | Wait:   12 | Proc:    2 |
# |         |            | Stop:   93 |            | Stop:  107 |            | Stop:  113 |            | Stop:  127 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  93 |            | Start: 107 |            | Start: 113 |            | Start: 127 |
# | Job: 21 | Wait:   93 | Proc:    3 | Wait:   11 | Proc:    1 | Wait:    5 | Proc:    5 | Wait:    9 | Proc:    2 |
# |         |            | Stop:   96 |            | Stop:  108 |            | Stop:  118 |            | Stop:  129 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  96 |            | Start: 108 |            | Start: 118 |            | Start: 129 |
# | Job:  9 | Wait:   96 | Proc:    3 | Wait:    9 | Proc:    8 | Wait:    2 | Proc:    2 | Wait:    9 | Proc:    5 |
# |         |            | Stop:   99 |            | Stop:  116 |            | Stop:  120 |            | Stop:  134 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  99 |            | Start: 116 |            | Start: 120 |            | Start: 134 |
# | Job: 15 | Wait:   99 | Proc:    4 | Wait:   13 | Proc:    3 | Wait:    1 | Proc:    3 | Wait:   11 | Proc:    6 |
# |         |            | Stop:  103 |            | Stop:  119 |            | Stop:  123 |            | Stop:  140 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 103 |            | Start: 119 |            | Start: 123 |            | Start: 140 |
# | Job:  1 | Wait:  103 | Proc:    2 | Wait:   14 | Proc:    1 | Wait:    3 | Proc:    3 | Wait:   14 | Proc:    2 |
# |         |            | Stop:  105 |            | Stop:  120 |            | Stop:  126 |            | Stop:  142 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 105 |            | Start: 120 |            | Start: 126 |            | Start: 142 |
# | Job: 14 | Wait:  105 | Proc:    5 | Wait:   10 | Proc:    1 | Wait:    5 | Proc:    7 | Wait:    9 | Proc:    3 |
# |         |            | Stop:  110 |            | Stop:  121 |            | Stop:  133 |            | Stop:  145 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 110 |            | Start: 121 |            | Start: 133 |            | Start: 145 |
# | Job: 45 | Wait:  110 | Proc:    5 | Wait:    6 | Proc:    3 | Wait:    9 | Proc:    8 | Wait:    4 | Proc:    4 |
# |         |            | Stop:  115 |            | Stop:  124 |            | Stop:  141 |            | Stop:  149 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 115 |            | Start: 124 |            | Start: 141 |            | Start: 149 |
# | Job: 32 | Wait:  115 | Proc:    8 | Wait:    1 | Proc:    1 | Wait:   16 | Proc:    2 | Wait:    6 | Proc:    7 |
# |         |            | Stop:  123 |            | Stop:  125 |            | Stop:  143 |            | Stop:  156 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 123 |            | Start: 125 |            | Start: 143 |            | Start: 156 |
# | Job: 47 | Wait:  123 | Proc:    1 | Wait:    1 | Proc:    9 | Wait:    9 | Proc:    5 | Wait:    8 | Proc:    4 |
# |         |            | Stop:  124 |            | Stop:  134 |            | Stop:  148 |            | Stop:  160 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 124 |            | Start: 134 |            | Start: 148 |            | Start: 160 |
# | Job: 44 | Wait:  124 | Proc:    7 | Wait:    3 | Proc:    2 | Wait:   12 | Proc:    2 | Wait:   10 | Proc:    8 |
# |         |            | Stop:  131 |            | Stop:  136 |            | Stop:  150 |            | Stop:  168 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 131 |            | Start: 137 |            | Start: 150 |            | Start: 168 |
# | Job: 22 | Wait:  131 | Proc:    6 | Wait:    0 | Proc:    2 | Wait:   11 | Proc:    9 | Wait:    9 | Proc:    6 |
# |         |            | Stop:  137 |            | Stop:  139 |            | Stop:  159 |            | Stop:  174 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 137 |            | Start: 140 |            | Start: 159 |            | Start: 174 |
# | Job: 46 | Wait:  137 | Proc:    3 | Wait:    0 | Proc:    4 | Wait:   15 | Proc:    6 | Wait:    9 | Proc:    4 |
# |         |            | Stop:  140 |            | Stop:  144 |            | Stop:  165 |            | Stop:  178 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    4 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 140 |            | Start: 148 |            | Start: 165 |            | Start: 178 |
# | Job: 12 | Wait:  140 | Proc:    8 | Wait:    0 | Proc:    7 | Wait:   10 | Proc:    2 | Wait:   11 | Proc:    5 |
# |         |            | Stop:  148 |            | Stop:  155 |            | Stop:  167 |            | Stop:  183 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 148 |            | Start: 155 |            | Start: 167 |            | Start: 183 |
# | Job: 41 | Wait:  148 | Proc:    1 | Wait:    6 | Proc:    7 | Wait:    5 | Proc:    4 | Wait:   12 | Proc:    9 |
# |         |            | Stop:  149 |            | Stop:  162 |            | Stop:  171 |            | Stop:  192 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 149 |            | Start: 162 |            | Start: 171 |            | Start: 192 |
# | Job: 33 | Wait:  149 | Proc:    3 | Wait:   10 | Proc:    1 | Wait:    8 | Proc:    4 | Wait:   17 | Proc:    8 |
# |         |            | Stop:  152 |            | Stop:  163 |            | Stop:  175 |            | Stop:  200 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 152 |            | Start: 163 |            | Start: 175 |            | Start: 200 |
# | Job: 19 | Wait:  152 | Proc:    9 | Wait:    2 | Proc:    8 | Wait:    4 | Proc:    1 | Wait:   24 | Proc:    8 |
# |         |            | Stop:  161 |            | Stop:  171 |            | Stop:  176 |            | Stop:  208 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 161 |            | Start: 171 |            | Start: 178 |            | Start: 208 |
# | Job: 34 | Wait:  161 | Proc:    9 | Wait:    1 | Proc:    7 | Wait:    0 | Proc:    7 | Wait:   23 | Proc:    3 |
# |         |            | Stop:  170 |            | Stop:  178 |            | Stop:  185 |            | Stop:  211 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 170 |            | Start: 178 |            | Start: 185 |            | Start: 211 |
# | Job:  0 | Wait:  170 | Proc:    5 | Wait:    3 | Proc:    1 | Wait:    6 | Proc:    9 | Wait:   17 | Proc:    7 |
# |         |            | Stop:  175 |            | Stop:  179 |            | Stop:  194 |            | Stop:  218 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 175 |            | Start: 181 |            | Start: 194 |            | Start: 218 |
# | Job: 28 | Wait:  175 | Proc:    6 | Wait:    0 | Proc:    5 | Wait:    8 | Proc:    8 | Wait:   16 | Proc:    9 |
# |         |            | Stop:  181 |            | Stop:  186 |            | Stop:  202 |            | Stop:  227 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 181 |            | Start: 186 |            | Start: 202 |            | Start: 227 |
# | Job: 37 | Wait:  181 | Proc:    4 | Wait:    1 | Proc:    3 | Wait:   13 | Proc:    7 | Wait:   18 | Proc:    5 |
# |         |            | Stop:  185 |            | Stop:  189 |            | Stop:  209 |            | Stop:  232 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    5 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 185 |            | Start: 194 |            | Start: 209 |            | Start: 232 |
# | Job: 40 | Wait:  185 | Proc:    9 | Wait:    0 | Proc:    1 | Wait:   14 | Proc:    4 | Wait:   19 | Proc:    9 |
# |         |            | Stop:  194 |            | Stop:  195 |            | Stop:  213 |            | Stop:  241 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    7 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 194 |            | Start: 202 |            | Start: 213 |            | Start: 241 |
# | Job: 36 | Wait:  194 | Proc:    8 | Wait:    0 | Proc:    6 | Wait:    5 | Proc:    6 | Wait:   22 | Proc:    2 |
# |         |            | Stop:  202 |            | Stop:  208 |            | Stop:  219 |            | Stop:  243 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 202 |            | Start: 208 |            | Start: 219 |            | Start: 243 |
# | Job:  7 | Wait:  202 | Proc:    5 | Wait:    1 | Proc:    7 | Wait:    4 | Proc:    2 | Wait:   22 | Proc:    8 |
# |         |            | Stop:  207 |            | Stop:  215 |            | Stop:  221 |            | Stop:  251 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 207 |            | Start: 215 |            | Start: 221 |            | Start: 251 |
# | Job: 25 | Wait:  207 | Proc:    6 | Wait:    2 | Proc:    3 | Wait:    3 | Proc:    6 | Wait:   24 | Proc:    2 |
# |         |            | Stop:  213 |            | Stop:  218 |            | Stop:  227 |            | Stop:  253 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 213 |            | Start: 218 |            | Start: 227 |            | Start: 253 |
# | Job: 35 | Wait:  213 | Proc:    5 | Wait:    0 | Proc:    7 | Wait:    2 | Proc:    3 | Wait:   23 | Proc:    1 |
# |         |            | Stop:  218 |            | Stop:  225 |            | Stop:  230 |            | Stop:  254 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 218 |            | Start: 225 |            | Start: 230 |            | Start: 254 |
# | Job: 13 | Wait:  218 | Proc:    3 | Wait:    4 | Proc:    5 | Wait:    0 | Proc:    6 | Wait:   18 | Proc:    1 |
# |         |            | Stop:  221 |            | Stop:  230 |            | Stop:  236 |            | Stop:  255 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 221 |            | Start: 230 |            | Start: 238 |            | Start: 255 |
# | Job: 24 | Wait:  221 | Proc:    6 | Wait:    3 | Proc:    8 | Wait:    0 | Proc:    2 | Wait:   15 | Proc:    2 |
# |         |            | Stop:  227 |            | Stop:  238 |            | Stop:  240 |            | Stop:  257 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    5 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 227 |            | Start: 238 |            | Start: 245 |            | Start: 257 |
# | Job:  8 | Wait:  227 | Proc:    3 | Wait:    8 | Proc:    7 | Wait:    0 | Proc:    4 | Wait:    8 | Proc:    7 |
# |         |            | Stop:  230 |            | Stop:  245 |            | Stop:  249 |            | Stop:  264 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 230 |            | Start: 245 |            | Start: 249 |            | Start: 264 |
# | Job:  2 | Wait:  230 | Proc:    9 | Wait:    6 | Proc:    2 | Wait:    2 | Proc:    5 | Wait:   10 | Proc:    1 |
# |         |            | Stop:  239 |            | Stop:  247 |            | Stop:  254 |            | Stop:  265 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# 265

# %% [markdown]
# ## Ant Colony Optimization

# %%
import random
import numpy as np

def AntColonyOptimization(PROC, n_ants=20, n_iterations=100, alpha=1.0, beta=2.0, evaporation_rate=0.5):
    N_JOBS = len(PROC)
    
    # Initialize pheromone levels
    pheromone = np.ones((N_JOBS, N_JOBS))
    best_seq = None
    best_time = float('inf')

    def calculate_probabilities(available_jobs, current_job):
        probabilities = []
        pheromones = []
        heuristics = []
        for job in available_jobs:
            pheromones.append(pheromone[current_job][job])
            heuristics.append(1.0 / PROC[job][0])  # Use job processing time on the first machine as a heuristic
        
        total_pheromone_heuristic = sum((p ** alpha) * (h ** beta) for p, h in zip(pheromones, heuristics))
        for p, h in zip(pheromones, heuristics):
            prob = ((p ** alpha) * (h ** beta)) / total_pheromone_heuristic
            probabilities.append(prob)
        return probabilities

    def update_pheromone(trail, time):
        for i in range(N_JOBS - 1):
            pheromone[trail[i]][trail[i + 1]] += 1.0 / time

    for iteration in range(n_iterations):
        all_trails = []
        all_times = []

        for ant in range(n_ants):
            trail = []
            available_jobs = list(range(N_JOBS))
            current_job = random.choice(available_jobs)
            trail.append(current_job)
            available_jobs.remove(current_job)

            while available_jobs:
                probabilities = calculate_probabilities(available_jobs, current_job)
                next_job = random.choices(available_jobs, probabilities)[0]
                trail.append(next_job)
                available_jobs.remove(next_job)
                current_job = next_job

            total_time = totalTime(PROC, trail)
            all_trails.append(trail)
            all_times.append(total_time)

            if total_time < best_time:
                best_time = total_time
                best_seq = trail

        # Evaporate pheromone
        pheromone *= (1.0 - evaporation_rate)

        # Update pheromone
        for trail, time in zip(all_trails, all_times):
            update_pheromone(trail, time)

    return best_seq, best_time

# %%
# Running the Ant Colony Optimization
seq, proctime = AntColonyOptimization(PROC)
print("Optimal job sequence:", seq)
print("Total processing time:", proctime)
# Out:
# Optimal job sequence: [17, 18, 41, 46, 20, 48, 31, 15, 39, 22, 33, 47, 16, 19, 35, 14, 37, 44, 4, 9, 49, 29, 38, 1, 13, 24, 7, 10, 3, 45, 5, 21, 40, 0, 27, 23, 2, 42, 6, 8, 25, 12, 26, 28, 34, 32, 36, 30, 43, 11]
# Total processing time: 263

# %%
# Logging the detailed process
totalTime(PROC, seq, log=True)
# Out:
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Machine: 0 |            | Machine: 1 |            | Machine: 2 |            | Machine: 3 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    5 |            | Idle:    6 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   0 |            | Start:   1 |            | Start:   5 |            | Start:   6 |
# | Job: 17 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    1 | Wait:    0 | Proc:    8 |
# |         |            | Stop:    1 |            | Stop:    5 |            | Stop:    6 |            | Stop:   14 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    4 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   1 |            | Start:   5 |            | Start:  10 |            | Start:  14 |
# | Job: 18 | Wait:    1 | Proc:    1 | Wait:    3 | Proc:    5 | Wait:    0 | Proc:    4 | Wait:    0 | Proc:    8 |
# |         |            | Stop:    2 |            | Stop:   10 |            | Stop:   14 |            | Stop:   22 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    3 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   2 |            | Start:  10 |            | Start:  17 |            | Start:  22 |
# | Job: 41 | Wait:    2 | Proc:    1 | Wait:    7 | Proc:    7 | Wait:    0 | Proc:    4 | Wait:    1 | Proc:    9 |
# |         |            | Stop:    3 |            | Stop:   17 |            | Stop:   21 |            | Stop:   31 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   3 |            | Start:  17 |            | Start:  21 |            | Start:  31 |
# | Job: 46 | Wait:    3 | Proc:    3 | Wait:   11 | Proc:    4 | Wait:    0 | Proc:    6 | Wait:    4 | Proc:    4 |
# |         |            | Stop:    6 |            | Stop:   21 |            | Stop:   27 |            | Stop:   35 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   6 |            | Start:  21 |            | Start:  27 |            | Start:  36 |
# | Job: 20 | Wait:    6 | Proc:    1 | Wait:   14 | Proc:    2 | Wait:    4 | Proc:    9 | Wait:    0 | Proc:    9 |
# |         |            | Stop:    7 |            | Stop:   23 |            | Stop:   36 |            | Stop:   45 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   7 |            | Start:  23 |            | Start:  36 |            | Start:  45 |
# | Job: 48 | Wait:    7 | Proc:    2 | Wait:   14 | Proc:    1 | Wait:   12 | Proc:    7 | Wait:    2 | Proc:    7 |
# |         |            | Stop:    9 |            | Stop:   24 |            | Stop:   43 |            | Stop:   52 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:   9 |            | Start:  24 |            | Start:  43 |            | Start:  52 |
# | Job: 31 | Wait:    9 | Proc:    4 | Wait:   11 | Proc:    4 | Wait:   15 | Proc:    1 | Wait:    8 | Proc:    3 |
# |         |            | Stop:   13 |            | Stop:   28 |            | Stop:   44 |            | Stop:   55 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  13 |            | Start:  28 |            | Start:  44 |            | Start:  55 |
# | Job: 15 | Wait:   13 | Proc:    4 | Wait:   11 | Proc:    3 | Wait:   13 | Proc:    3 | Wait:    8 | Proc:    6 |
# |         |            | Stop:   17 |            | Stop:   31 |            | Stop:   47 |            | Stop:   61 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  17 |            | Start:  31 |            | Start:  47 |            | Start:  61 |
# | Job: 39 | Wait:   17 | Proc:    1 | Wait:   13 | Proc:    2 | Wait:   14 | Proc:    5 | Wait:    9 | Proc:    3 |
# |         |            | Stop:   18 |            | Stop:   33 |            | Stop:   52 |            | Stop:   64 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  18 |            | Start:  33 |            | Start:  52 |            | Start:  64 |
# | Job: 22 | Wait:   18 | Proc:    6 | Wait:    9 | Proc:    2 | Wait:   17 | Proc:    9 | Wait:    3 | Proc:    6 |
# |         |            | Stop:   24 |            | Stop:   35 |            | Stop:   61 |            | Stop:   70 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  24 |            | Start:  35 |            | Start:  61 |            | Start:  70 |
# | Job: 33 | Wait:   24 | Proc:    3 | Wait:    8 | Proc:    1 | Wait:   25 | Proc:    4 | Wait:    5 | Proc:    8 |
# |         |            | Stop:   27 |            | Stop:   36 |            | Stop:   65 |            | Stop:   78 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  27 |            | Start:  36 |            | Start:  65 |            | Start:  78 |
# | Job: 47 | Wait:   27 | Proc:    1 | Wait:    8 | Proc:    9 | Wait:   20 | Proc:    5 | Wait:    8 | Proc:    4 |
# |         |            | Stop:   28 |            | Stop:   45 |            | Stop:   70 |            | Stop:   82 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  28 |            | Start:  45 |            | Start:  70 |            | Start:  82 |
# | Job: 16 | Wait:   28 | Proc:    2 | Wait:   15 | Proc:    9 | Wait:   16 | Proc:    5 | Wait:    7 | Proc:    2 |
# |         |            | Stop:   30 |            | Stop:   54 |            | Stop:   75 |            | Stop:   84 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  30 |            | Start:  54 |            | Start:  75 |            | Start:  84 |
# | Job: 19 | Wait:   30 | Proc:    9 | Wait:   15 | Proc:    8 | Wait:   13 | Proc:    1 | Wait:    8 | Proc:    8 |
# |         |            | Stop:   39 |            | Stop:   62 |            | Stop:   76 |            | Stop:   92 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  39 |            | Start:  62 |            | Start:  76 |            | Start:  92 |
# | Job: 35 | Wait:   39 | Proc:    5 | Wait:   18 | Proc:    7 | Wait:    7 | Proc:    3 | Wait:   13 | Proc:    1 |
# |         |            | Stop:   44 |            | Stop:   69 |            | Stop:   79 |            | Stop:   93 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  44 |            | Start:  69 |            | Start:  79 |            | Start:  93 |
# | Job: 14 | Wait:   44 | Proc:    5 | Wait:   20 | Proc:    1 | Wait:    9 | Proc:    7 | Wait:    7 | Proc:    3 |
# |         |            | Stop:   49 |            | Stop:   70 |            | Stop:   86 |            | Stop:   96 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  49 |            | Start:  70 |            | Start:  86 |            | Start:  96 |
# | Job: 37 | Wait:   49 | Proc:    4 | Wait:   17 | Proc:    3 | Wait:   13 | Proc:    7 | Wait:    3 | Proc:    5 |
# |         |            | Stop:   53 |            | Stop:   73 |            | Stop:   93 |            | Stop:  101 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  53 |            | Start:  73 |            | Start:  93 |            | Start: 101 |
# | Job: 44 | Wait:   53 | Proc:    7 | Wait:   13 | Proc:    2 | Wait:   18 | Proc:    2 | Wait:    6 | Proc:    8 |
# |         |            | Stop:   60 |            | Stop:   75 |            | Stop:   95 |            | Stop:  109 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  60 |            | Start:  75 |            | Start:  95 |            | Start: 109 |
# | Job:  4 | Wait:   60 | Proc:    2 | Wait:   13 | Proc:    3 | Wait:   17 | Proc:    2 | Wait:   12 | Proc:    8 |
# |         |            | Stop:   62 |            | Stop:   78 |            | Stop:   97 |            | Stop:  117 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  62 |            | Start:  78 |            | Start:  97 |            | Start: 117 |
# | Job:  9 | Wait:   62 | Proc:    3 | Wait:   13 | Proc:    8 | Wait:   11 | Proc:    2 | Wait:   18 | Proc:    5 |
# |         |            | Stop:   65 |            | Stop:   86 |            | Stop:   99 |            | Stop:  122 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  65 |            | Start:  86 |            | Start:  99 |            | Start: 122 |
# | Job: 49 | Wait:   65 | Proc:    2 | Wait:   19 | Proc:    6 | Wait:    7 | Proc:    4 | Wait:   19 | Proc:    2 |
# |         |            | Stop:   67 |            | Stop:   92 |            | Stop:  103 |            | Stop:  124 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  67 |            | Start:  92 |            | Start: 103 |            | Start: 124 |
# | Job: 29 | Wait:   67 | Proc:    6 | Wait:   19 | Proc:    2 | Wait:    9 | Proc:    5 | Wait:   16 | Proc:    6 |
# |         |            | Stop:   73 |            | Stop:   94 |            | Stop:  108 |            | Stop:  130 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  73 |            | Start:  94 |            | Start: 108 |            | Start: 130 |
# | Job: 38 | Wait:   73 | Proc:    4 | Wait:   17 | Proc:    3 | Wait:   11 | Proc:    6 | Wait:   16 | Proc:    4 |
# |         |            | Stop:   77 |            | Stop:   97 |            | Stop:  114 |            | Stop:  134 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  77 |            | Start:  97 |            | Start: 114 |            | Start: 134 |
# | Job:  1 | Wait:   77 | Proc:    2 | Wait:   18 | Proc:    1 | Wait:   16 | Proc:    3 | Wait:   17 | Proc:    2 |
# |         |            | Stop:   79 |            | Stop:   98 |            | Stop:  117 |            | Stop:  136 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  79 |            | Start:  98 |            | Start: 117 |            | Start: 136 |
# | Job: 13 | Wait:   79 | Proc:    3 | Wait:   16 | Proc:    5 | Wait:   14 | Proc:    6 | Wait:   13 | Proc:    1 |
# |         |            | Stop:   82 |            | Stop:  103 |            | Stop:  123 |            | Stop:  137 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  82 |            | Start: 103 |            | Start: 123 |            | Start: 137 |
# | Job: 24 | Wait:   82 | Proc:    6 | Wait:   15 | Proc:    8 | Wait:   12 | Proc:    2 | Wait:   12 | Proc:    2 |
# |         |            | Stop:   88 |            | Stop:  111 |            | Stop:  125 |            | Stop:  139 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  88 |            | Start: 111 |            | Start: 125 |            | Start: 139 |
# | Job:  7 | Wait:   88 | Proc:    5 | Wait:   18 | Proc:    7 | Wait:    7 | Proc:    2 | Wait:   12 | Proc:    8 |
# |         |            | Stop:   93 |            | Stop:  118 |            | Stop:  127 |            | Stop:  147 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  93 |            | Start: 118 |            | Start: 127 |            | Start: 147 |
# | Job: 10 | Wait:   93 | Proc:    5 | Wait:   20 | Proc:    9 | Wait:    0 | Proc:    8 | Wait:   12 | Proc:    1 |
# |         |            | Stop:   98 |            | Stop:  127 |            | Stop:  135 |            | Stop:  148 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start:  98 |            | Start: 127 |            | Start: 135 |            | Start: 148 |
# | Job:  3 | Wait:   98 | Proc:    9 | Wait:   20 | Proc:    7 | Wait:    1 | Proc:    6 | Wait:    7 | Proc:    9 |
# |         |            | Stop:  107 |            | Stop:  134 |            | Stop:  141 |            | Stop:  157 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 107 |            | Start: 134 |            | Start: 141 |            | Start: 157 |
# | Job: 45 | Wait:  107 | Proc:    5 | Wait:   22 | Proc:    3 | Wait:    4 | Proc:    8 | Wait:    8 | Proc:    4 |
# |         |            | Stop:  112 |            | Stop:  137 |            | Stop:  149 |            | Stop:  161 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 112 |            | Start: 137 |            | Start: 149 |            | Start: 161 |
# | Job:  5 | Wait:  112 | Proc:    3 | Wait:   22 | Proc:    7 | Wait:    5 | Proc:    5 | Wait:    7 | Proc:    6 |
# |         |            | Stop:  115 |            | Stop:  144 |            | Stop:  154 |            | Stop:  167 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 115 |            | Start: 144 |            | Start: 154 |            | Start: 167 |
# | Job: 21 | Wait:  115 | Proc:    3 | Wait:   26 | Proc:    1 | Wait:    9 | Proc:    5 | Wait:    8 | Proc:    2 |
# |         |            | Stop:  118 |            | Stop:  145 |            | Stop:  159 |            | Stop:  169 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 118 |            | Start: 145 |            | Start: 159 |            | Start: 169 |
# | Job: 40 | Wait:  118 | Proc:    9 | Wait:   18 | Proc:    1 | Wait:   13 | Proc:    4 | Wait:    6 | Proc:    9 |
# |         |            | Stop:  127 |            | Stop:  146 |            | Stop:  163 |            | Stop:  178 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 127 |            | Start: 146 |            | Start: 163 |            | Start: 178 |
# | Job:  0 | Wait:  127 | Proc:    5 | Wait:   14 | Proc:    1 | Wait:   16 | Proc:    9 | Wait:    6 | Proc:    7 |
# |         |            | Stop:  132 |            | Stop:  147 |            | Stop:  172 |            | Stop:  185 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 132 |            | Start: 147 |            | Start: 172 |            | Start: 185 |
# | Job: 27 | Wait:  132 | Proc:    3 | Wait:   12 | Proc:    4 | Wait:   21 | Proc:    1 | Wait:   12 | Proc:    9 |
# |         |            | Stop:  135 |            | Stop:  151 |            | Stop:  173 |            | Stop:  194 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 135 |            | Start: 151 |            | Start: 173 |            | Start: 194 |
# | Job: 23 | Wait:  135 | Proc:    4 | Wait:   12 | Proc:    3 | Wait:   19 | Proc:    4 | Wait:   17 | Proc:    8 |
# |         |            | Stop:  139 |            | Stop:  154 |            | Stop:  177 |            | Stop:  202 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 139 |            | Start: 154 |            | Start: 177 |            | Start: 202 |
# | Job:  2 | Wait:  139 | Proc:    9 | Wait:    6 | Proc:    2 | Wait:   21 | Proc:    5 | Wait:   20 | Proc:    1 |
# |         |            | Stop:  148 |            | Stop:  156 |            | Stop:  182 |            | Stop:  203 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 148 |            | Start: 156 |            | Start: 182 |            | Start: 203 |
# | Job: 42 | Wait:  148 | Proc:    4 | Wait:    4 | Proc:    5 | Wait:   21 | Proc:    1 | Wait:   20 | Proc:    8 |
# |         |            | Stop:  152 |            | Stop:  161 |            | Stop:  183 |            | Stop:  211 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 152 |            | Start: 161 |            | Start: 183 |            | Start: 211 |
# | Job:  6 | Wait:  152 | Proc:    8 | Wait:    1 | Proc:    3 | Wait:   19 | Proc:    2 | Wait:   26 | Proc:    1 |
# |         |            | Stop:  160 |            | Stop:  164 |            | Stop:  185 |            | Stop:  212 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 160 |            | Start: 164 |            | Start: 185 |            | Start: 212 |
# | Job:  8 | Wait:  160 | Proc:    3 | Wait:    1 | Proc:    7 | Wait:   14 | Proc:    4 | Wait:   23 | Proc:    7 |
# |         |            | Stop:  163 |            | Stop:  171 |            | Stop:  189 |            | Stop:  219 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 163 |            | Start: 171 |            | Start: 189 |            | Start: 219 |
# | Job: 25 | Wait:  163 | Proc:    6 | Wait:    2 | Proc:    3 | Wait:   15 | Proc:    6 | Wait:   24 | Proc:    2 |
# |         |            | Stop:  169 |            | Stop:  174 |            | Stop:  195 |            | Stop:  221 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    3 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 169 |            | Start: 177 |            | Start: 195 |            | Start: 221 |
# | Job: 12 | Wait:  169 | Proc:    8 | Wait:    0 | Proc:    7 | Wait:   11 | Proc:    2 | Wait:   24 | Proc:    5 |
# |         |            | Stop:  177 |            | Stop:  184 |            | Stop:  197 |            | Stop:  226 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    2 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 177 |            | Start: 186 |            | Start: 197 |            | Start: 226 |
# | Job: 26 | Wait:  177 | Proc:    9 | Wait:    0 | Proc:    1 | Wait:   10 | Proc:    3 | Wait:   26 | Proc:    2 |
# |         |            | Stop:  186 |            | Stop:  187 |            | Stop:  200 |            | Stop:  228 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    5 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 186 |            | Start: 192 |            | Start: 200 |            | Start: 228 |
# | Job: 28 | Wait:  186 | Proc:    6 | Wait:    0 | Proc:    5 | Wait:    3 | Proc:    8 | Wait:   20 | Proc:    9 |
# |         |            | Stop:  192 |            | Stop:  197 |            | Stop:  208 |            | Stop:  237 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    4 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 192 |            | Start: 201 |            | Start: 208 |            | Start: 237 |
# | Job: 34 | Wait:  192 | Proc:    9 | Wait:    0 | Proc:    7 | Wait:    0 | Proc:    7 | Wait:   22 | Proc:    3 |
# |         |            | Stop:  201 |            | Stop:  208 |            | Stop:  215 |            | Stop:  240 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 201 |            | Start: 209 |            | Start: 215 |            | Start: 240 |
# | Job: 32 | Wait:  201 | Proc:    8 | Wait:    0 | Proc:    1 | Wait:    5 | Proc:    2 | Wait:   23 | Proc:    7 |
# |         |            | Stop:  209 |            | Stop:  210 |            | Stop:  217 |            | Stop:  247 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    7 |            | Idle:    6 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 209 |            | Start: 217 |            | Start: 223 |            | Start: 247 |
# | Job: 36 | Wait:  209 | Proc:    8 | Wait:    0 | Proc:    6 | Wait:    0 | Proc:    6 | Wait:   18 | Proc:    2 |
# |         |            | Stop:  217 |            | Stop:  223 |            | Stop:  229 |            | Stop:  249 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    3 |            | Idle:    5 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 217 |            | Start: 226 |            | Start: 234 |            | Start: 249 |
# | Job: 30 | Wait:  217 | Proc:    9 | Wait:    0 | Proc:    8 | Wait:    0 | Proc:    3 | Wait:   12 | Proc:    6 |
# |         |            | Stop:  226 |            | Stop:  234 |            | Stop:  237 |            | Stop:  255 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    5 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 226 |            | Start: 234 |            | Start: 242 |            | Start: 255 |
# | Job: 43 | Wait:  226 | Proc:    8 | Wait:    0 | Proc:    8 | Wait:    0 | Proc:    3 | Wait:   10 | Proc:    1 |
# |         |            | Stop:  234 |            | Stop:  242 |            | Stop:  245 |            | Stop:  256 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Idle:    0 |            | Idle:    0 |            | Idle:    1 |            | Idle:    0 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# |         |            | Start: 234 |            | Start: 242 |            | Start: 246 |            | Start: 256 |
# | Job: 11 | Wait:  234 | Proc:    5 | Wait:    3 | Proc:    4 | Wait:    0 | Proc:    5 | Wait:    5 | Proc:    7 |
# |         |            | Stop:  239 |            | Stop:  246 |            | Stop:  251 |            | Stop:  263 |
# |---------|------------|------------|------------|------------|------------|------------|------------|------------|
# 263
